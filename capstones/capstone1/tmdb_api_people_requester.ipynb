# %%
raise SystemExit("Stop right there!")

# %%
import requests
import json
import pandas as pd
from IPython.display import clear_output
from time import sleep
import numpy as np

# %%
# retrieve my TMDb key
local_file = 'tmdb_key.txt'
with open(local_file, 'r') as api_file:
    my_key = api_file.read().rstrip('\r\n')
    api_file.close()

# %%
# set first part of URL for every request
base_url = 'https://api.themoviedb.org/3/'

# %%
def make_request(_id, prior_attempts=0):
    """Makes requests for all person objects in TMDb database and stores them in a list of JSON's"""
    if prior_attempts == 3:
        return {}
    url = base_url + 'person/' + str(_id) + '?api_key=' + my_key
    response = requests.get(url)
    # entry not found
    if response.status_code == 404:
        return {}
    # exceed rate limit
    if response.status_code == 429:
        sleep(10)
        return make_request(_id=_id)
    # success
    if response.status_code == 200:
        return response.json()
    else:
        sleep(1)
        return make_request(_id=_id, prior_attempts=prior_attempts + 1)

# %%
def get_people(num):
    """Makes requests for all person objects in TMDb database and stores them in a list of JSON's"""
    people_list = []
    for val in range(num - 99999, num + 1):
        print(val)
        clear_output(wait=True)
        people_list.append(make_request(_id=val))
    return people_list

# %%
df_100k = pd.read_json('tmdb_person_100k.json')
df_100k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              36541 non-null  object
#  1   known_for_department  84356 non-null  object
#  2   deathday              12317 non-null  object
#  3   id                    84367 non-null  float64
#  4   name                  84367 non-null  object
#  5   also_known_as         84367 non-null  object
#  6   gender                84367 non-null  float64
#  7   biography             84367 non-null  object
#  8   popularity            84367 non-null  float64
#  9   place_of_birth        30895 non-null  object
#  10  profile_path          20826 non-null  object
#  11  adult                 84367 non-null  float64
#  12  imdb_id               84367 non-null  object
#  13  homepage              3667 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_100k.head().transpose()
# Out:
#                                                                       0  \
# birthday                                                     1944-05-14
# known_for_department                                          Directing
# deathday                                                           None
# id                                                                    1
# name                                                       George Lucas
# also_known_as         [George Walton Lucas Jr. , 乔治·卢卡斯, Джордж Лука...
# gender                                                                2
# biography             George Walton Lucas Jr. (born May 14, 1944) is...
# popularity                                                        6.761
# place_of_birth                                 Modesto, California, USA
# profile_path                           /mDLDvsx8PaZoEThkBdyaG1JxPdf.jpg
# adult                                                                 0
# imdb_id                                                       nm0000184
# homepage                                                           None
#
#                                                                       1  \
# birthday                                                     1951-09-25
# known_for_department                                             Acting
# deathday                                                           None
# id                                                                    2
# name                                                        Mark Hamill
# also_known_as         [Mark Hamil, Mark Richard Hamill, Марк Хэмилл,...
# gender                                                                2
# biography             Mark Richard Hamill (born September 25, 1951) ...
# popularity                                                       10.497
# place_of_birth                                 Concord, California, USA
# profile_path                           /fk8OfdReNltKZqOk2TZgkofCUFq.jpg
# adult                                                                 0
# imdb_id                                                       nm0000434
# homepage                                                           None
#
#                                                                       2  \
# birthday                                                     1942-07-13
# known_for_department                                             Acting
# deathday                                                           None
# id                                                                    3
# name                                                      Harrison Ford
# also_known_as         [Гаррісон Форд, Харрисон Форд, هاريسون فورد, 해...
# gender                                                                2
# biography             Legendary Hollywood Icon Harrison Ford was bor...
# popularity                                                       20.349
# place_of_birth                                   Chicago, Illinois, USA
# profile_path                           /5M7oN3sznp99hWYQ9sX0xheswWX.jpg
# adult                                                                 0
# imdb_id                                                       nm0000148
# homepage                                                           None
#
#                                                                       3  \
# birthday                                                     1956-10-21
# known_for_department                                             Acting
# deathday                                                     2016-12-27
# id                                                                    4
# name                                                      Carrie Fisher
# also_known_as         [Carrie Frances Fisher , Кэрри Фишер, Кэрри Фр...
# gender                                                                1
# biography             Carrie Frances Fisher (21 October 1956 - 27 De...
# popularity                                                        7.228
# place_of_birth              Beverly Hills, Los Angeles, California, USA
# profile_path                           /rfJtncHewKVnHjqpIZvjn24ESeC.jpg
# adult                                                                 0
# imdb_id                                                       nm0000402
# homepage                                      https://carriefisher.com/
#
#                                                                       4
# birthday                                                     1913-05-26
# known_for_department                                             Acting
# deathday                                                     1994-08-11
# id                                                                    5
# name                                                      Peter Cushing
# also_known_as                                    [Peter Wilton Cushing]
# gender                                                                2
# biography             Peter Wilton Cushing, OBE  (26 May 1913 – 11 A...
# popularity                                                        3.902
# place_of_birth                              Kenley, Surrey, England, UK
# profile_path                            /1qtKVu16REL2YLVrhayjVey4al.jpg
# adult                                                                 0
# imdb_id                                                       nm0001088
# homepage                                                           None

# %%
df_100k.tail()
# Out:
#       birthday known_for_department deathday        id              name  \
# 99995     None               Acting     None   99996.0    Scooter McCrae
# 99996     None            Directing     None   99997.0     Eric Thornett
# 99997     None               Acting     None   99998.0       Jason Wauer
# 99998     None               Acting     None   99999.0             Mr. ?
# 99999     None               Acting     None  100000.0  Demetrius Parker
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                 0.631           None         None
# 99996            []     0.0                 0.600           None         None
# 99997            []     0.0                 0.600           None         None
# 99998            []     0.0                 0.600           None         None
# 99999            []     0.0                 0.600           None         None
#
#        adult    imdb_id homepage
# 99995    0.0  nm0566885     None
# 99996    0.0  nm1204419     None
# 99997    0.0  nm1312267     None
# 99998    0.0  nm2425757     None
# 99999    0.0  nm1203784     None

# %%
df = pd.DataFrame(get_people(num=200000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              17683 non-null  object
#  1   known_for_department  53328 non-null  object
#  2   deathday              6015 non-null   object
#  3   id                    53342 non-null  float64
#  4   name                  53342 non-null  object
#  5   also_known_as         53342 non-null  object
#  6   gender                53342 non-null  float64
#  7   biography             53342 non-null  object
#  8   popularity            53342 non-null  float64
#  9   place_of_birth        14275 non-null  object
#  10  profile_path          11130 non-null  object
#  11  adult                 53342 non-null  object
#  12  imdb_id               53342 non-null  object
#  13  homepage              1672 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_200k.json')

# %%
df_200k = pd.read_json('tmdb_person_200k.json')
df_200k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              17683 non-null  object
#  1   known_for_department  53328 non-null  object
#  2   deathday              6015 non-null   object
#  3   id                    53342 non-null  float64
#  4   name                  53342 non-null  object
#  5   also_known_as         53342 non-null  object
#  6   gender                53342 non-null  float64
#  7   biography             53342 non-null  object
#  8   popularity            53342 non-null  float64
#  9   place_of_birth        14275 non-null  object
#  10  profile_path          11130 non-null  object
#  11  adult                 53342 non-null  float64
#  12  imdb_id               53342 non-null  object
#  13  homepage              1672 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_200k.head().transpose()
# Out:
#                                0               1                  2  \
# birthday                    None            None               None
# known_for_department      Acting          Acting             Acting
# deathday                    None            None               None
# id                        100001          100002             100003
# name                  Peter Smak  Christi Etcher   Clancey McCauley
# also_known_as                 []              []  [Clancy McCauley]
# gender                         0               0                  1
# biography
# popularity                   0.6             0.6                0.6
# place_of_birth              None            None               None
# profile_path                None            None               None
# adult                          0               0                  0
# imdb_id                nm1205148       nm1312371          nm1077352
# homepage                    None            None               None
#
#                                  3            4
# birthday                      None         None
# known_for_department        Acting       Acting
# deathday                      None         None
# id                          100004       100005
# name                  Theresa Hoyt  Tara Durham
# also_known_as                   []           []
# gender                           0            0
# biography
# popularity                     0.6          0.6
# place_of_birth                None         None
# profile_path                  None         None
# adult                            0            0
# imdb_id
# homepage                      None         None

# %%
df_200k.tail()
# Out:
#       birthday known_for_department deathday        id            name  \
# 99995     None                 None     None       NaN            None
# 99996     None               Acting     None  199997.0    Jean O'Neill
# 99997     None           Production     None  199998.0       Jim Milio
# 99998     None               Acting     None  199999.0  Alistair Cooke
# 99999     None                 None     None       NaN            None
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995          None     NaN      None         NaN           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     0.0                   0.6           None         None
# 99999          None     NaN      None         NaN           None         None
#
#        adult    imdb_id homepage
# 99995    NaN       None     None
# 99996    0.0  nm0642196     None
# 99997    0.0                None
# 99998    0.0                None
# 99999    NaN       None     None

# %%
df = pd.DataFrame(get_people(num=300000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              6169 non-null   object
#  1   known_for_department  20913 non-null  object
#  2   deathday              1398 non-null   object
#  3   id                    20924 non-null  float64
#  4   name                  20924 non-null  object
#  5   also_known_as         20924 non-null  object
#  6   gender                20924 non-null  float64
#  7   biography             20924 non-null  object
#  8   popularity            20924 non-null  float64
#  9   place_of_birth        4969 non-null   object
#  10  profile_path          4342 non-null   object
#  11  adult                 20924 non-null  object
#  12  imdb_id               20924 non-null  object
#  13  homepage              835 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_300k.json')

# %%
df_300k = pd.read_json('tmdb_person_300k.json')
df_300k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              6169 non-null   object
#  1   known_for_department  20913 non-null  object
#  2   deathday              1398 non-null   object
#  3   id                    20924 non-null  float64
#  4   name                  20924 non-null  object
#  5   also_known_as         20924 non-null  object
#  6   gender                20924 non-null  float64
#  7   biography             20924 non-null  object
#  8   popularity            20924 non-null  float64
#  9   place_of_birth        4969 non-null   object
#  10  profile_path          4342 non-null   object
#  11  adult                 20924 non-null  float64
#  12  imdb_id               20924 non-null  object
#  13  homepage              835 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_300k.head().transpose()
# Out:
#                          0              1     2     3  \
# birthday              None           None  None  None
# known_for_department  None         Acting  None  None
# deathday              None           None  None  None
# id                     NaN         200002   NaN   NaN
# name                  None  Nicole Bailey  None  None
# also_known_as         None             []  None  None
# gender                 NaN              0   NaN   NaN
# biography             None                 None  None
# popularity             NaN            0.6   NaN   NaN
# place_of_birth        None           None  None  None
# profile_path          None           None  None  None
# adult                  NaN              0   NaN   NaN
# imdb_id               None      nm4797625  None  None
# homepage              None           None  None  None
#
#                                                      4
# birthday                                          None
# known_for_department                            Acting
# deathday                                          None
# id                                              200005
# name                                       Akeem Smith
# also_known_as                                       []
# gender                                               0
# biography
# popularity                                         0.6
# place_of_birth                                    None
# profile_path          /su1heQFA5KqgFaVlYwhgO8qecnb.jpg
# adult                                                0
# imdb_id                                      nm1576004
# homepage                                          None

# %%
df_300k.tail()
# Out:
#       birthday known_for_department deathday  id  name also_known_as  gender  \
# 99995     None                 None     None NaN  None          None     NaN
# 99996     None                 None     None NaN  None          None     NaN
# 99997     None                 None     None NaN  None          None     NaN
# 99998     None                 None     None NaN  None          None     NaN
# 99999     None                 None     None NaN  None          None     NaN
#
#       biography  popularity place_of_birth profile_path  adult imdb_id  \
# 99995      None         NaN           None         None    NaN    None
# 99996      None         NaN           None         None    NaN    None
# 99997      None         NaN           None         None    NaN    None
# 99998      None         NaN           None         None    NaN    None
# 99999      None         NaN           None         None    NaN    None
#
#       homepage
# 99995     None
# 99996     None
# 99997     None
# 99998     None
# 99999     None

# %%
df = pd.DataFrame(get_people(num=400000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              283 non-null    object
#  1   known_for_department  948 non-null    object
#  2   deathday              105 non-null    object
#  3   id                    948 non-null    float64
#  4   name                  948 non-null    object
#  5   also_known_as         948 non-null    object
#  6   gender                948 non-null    float64
#  7   biography             948 non-null    object
#  8   popularity            948 non-null    float64
#  9   place_of_birth        194 non-null    object
#  10  profile_path          166 non-null    object
#  11  adult                 948 non-null    object
#  12  imdb_id               948 non-null    object
#  13  homepage              20 non-null     object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_400k.json')

# %%
df_400k = pd.read_json('tmdb_person_400k.json')
df_400k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              283 non-null    object
#  1   known_for_department  948 non-null    object
#  2   deathday              105 non-null    object
#  3   id                    948 non-null    float64
#  4   name                  948 non-null    object
#  5   also_known_as         948 non-null    object
#  6   gender                948 non-null    float64
#  7   biography             948 non-null    object
#  8   popularity            948 non-null    float64
#  9   place_of_birth        194 non-null    object
#  10  profile_path          166 non-null    object
#  11  adult                 948 non-null    float64
#  12  imdb_id               948 non-null    object
#  13  homepage              20 non-null     object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_400k.head().transpose()
# Out:
#                          0     1                                  2     3  \
# birthday              None  None                         1901-07-29  None
# known_for_department  None  None                             Acting  None
# deathday              None  None                         1975-04-15  None
# id                     NaN   NaN                             300003   NaN
# name                  None  None                     Magnus Kesster  None
# also_known_as         None  None                                 []  None
# gender                 NaN   NaN                                  2   NaN
# biography             None  None                                     None
# popularity             NaN   NaN                                0.6   NaN
# place_of_birth        None  None  Stockholm, Stockholms län, Sweden  None
# profile_path          None  None   /vp2VHu78CUgtVGd88Ny72HC0n95.jpg  None
# adult                  NaN   NaN                                  0   NaN
# imdb_id               None  None                          nm0450408  None
# homepage              None  None                               None  None
#
#                          4
# birthday              None
# known_for_department  None
# deathday              None
# id                     NaN
# name                  None
# also_known_as         None
# gender                 NaN
# biography             None
# popularity             NaN
# place_of_birth        None
# profile_path          None
# adult                  NaN
# imdb_id               None
# homepage              None

# %%
df_400k.tail()
# Out:
#       birthday known_for_department deathday  id  name also_known_as  gender  \
# 99995     None                 None     None NaN  None          None     NaN
# 99996     None                 None     None NaN  None          None     NaN
# 99997     None                 None     None NaN  None          None     NaN
# 99998     None                 None     None NaN  None          None     NaN
# 99999     None                 None     None NaN  None          None     NaN
#
#       biography  popularity place_of_birth profile_path  adult imdb_id  \
# 99995      None         NaN           None         None    NaN    None
# 99996      None         NaN           None         None    NaN    None
# 99997      None         NaN           None         None    NaN    None
# 99998      None         NaN           None         None    NaN    None
# 99999      None         NaN           None         None    NaN    None
#
#       homepage
# 99995     None
# 99996     None
# 99997     None
# 99998     None
# 99999     None

# %%
df = pd.DataFrame(get_people(num=500000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              405 non-null    object
#  1   known_for_department  1222 non-null   object
#  2   deathday              64 non-null     object
#  3   id                    1222 non-null   float64
#  4   name                  1222 non-null   object
#  5   also_known_as         1222 non-null   object
#  6   gender                1222 non-null   float64
#  7   biography             1222 non-null   object
#  8   popularity            1222 non-null   float64
#  9   place_of_birth        285 non-null    object
#  10  profile_path          231 non-null    object
#  11  adult                 1222 non-null   object
#  12  imdb_id               1222 non-null   object
#  13  homepage              45 non-null     object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_500k.json')

# %%
df_500k = pd.read_json('tmdb_person_500k.json')
df_500k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              405 non-null    object
#  1   known_for_department  1222 non-null   object
#  2   deathday              64 non-null     object
#  3   id                    1222 non-null   float64
#  4   name                  1222 non-null   object
#  5   also_known_as         1222 non-null   object
#  6   gender                1222 non-null   float64
#  7   biography             1222 non-null   object
#  8   popularity            1222 non-null   float64
#  9   place_of_birth        285 non-null    object
#  10  profile_path          231 non-null    object
#  11  adult                 1222 non-null   float64
#  12  imdb_id               1222 non-null   object
#  13  homepage              45 non-null     object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_500k.head().transpose()
# Out:
#                          0     1     2     3     4
# birthday              None  None  None  None  None
# known_for_department  None  None  None  None  None
# deathday              None  None  None  None  None
# id                     NaN   NaN   NaN   NaN   NaN
# name                  None  None  None  None  None
# also_known_as         None  None  None  None  None
# gender                 NaN   NaN   NaN   NaN   NaN
# biography             None  None  None  None  None
# popularity             NaN   NaN   NaN   NaN   NaN
# place_of_birth        None  None  None  None  None
# profile_path          None  None  None  None  None
# adult                  NaN   NaN   NaN   NaN   NaN
# imdb_id               None  None  None  None  None
# homepage              None  None  None  None  None

# %%
df_500k.tail()
# Out:
#       birthday known_for_department deathday  id  name also_known_as  gender  \
# 99995     None                 None     None NaN  None          None     NaN
# 99996     None                 None     None NaN  None          None     NaN
# 99997     None                 None     None NaN  None          None     NaN
# 99998     None                 None     None NaN  None          None     NaN
# 99999     None                 None     None NaN  None          None     NaN
#
#       biography  popularity place_of_birth profile_path  adult imdb_id  \
# 99995      None         NaN           None         None    NaN    None
# 99996      None         NaN           None         None    NaN    None
# 99997      None         NaN           None         None    NaN    None
# 99998      None         NaN           None         None    NaN    None
# 99999      None         NaN           None         None    NaN    None
#
#       homepage
# 99995     None
# 99996     None
# 99997     None
# 99998     None
# 99999     None

# %%
df = pd.DataFrame(get_people(num=600000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              6494 non-null   object
#  1   known_for_department  29241 non-null  object
#  2   deathday              1997 non-null   object
#  3   id                    29246 non-null  float64
#  4   name                  29246 non-null  object
#  5   also_known_as         29246 non-null  object
#  6   gender                29246 non-null  float64
#  7   biography             29246 non-null  object
#  8   popularity            29246 non-null  float64
#  9   place_of_birth        5187 non-null   object
#  10  profile_path          4889 non-null   object
#  11  adult                 29246 non-null  object
#  12  imdb_id               29246 non-null  object
#  13  homepage              713 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_600k.json')

# %%
df_600k = pd.read_json('tmdb_person_600k.json')
df_600k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              6494 non-null   object
#  1   known_for_department  29241 non-null  object
#  2   deathday              1997 non-null   object
#  3   id                    29246 non-null  float64
#  4   name                  29246 non-null  object
#  5   also_known_as         29246 non-null  object
#  6   gender                29246 non-null  float64
#  7   biography             29246 non-null  object
#  8   popularity            29246 non-null  float64
#  9   place_of_birth        5187 non-null   object
#  10  profile_path          4889 non-null   object
#  11  adult                 29246 non-null  float64
#  12  imdb_id               29246 non-null  object
#  13  homepage              713 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_600k.head().transpose()
# Out:
#                          0     1     2     3     4
# birthday              None  None  None  None  None
# known_for_department  None  None  None  None  None
# deathday              None  None  None  None  None
# id                     NaN   NaN   NaN   NaN   NaN
# name                  None  None  None  None  None
# also_known_as         None  None  None  None  None
# gender                 NaN   NaN   NaN   NaN   NaN
# biography             None  None  None  None  None
# popularity             NaN   NaN   NaN   NaN   NaN
# place_of_birth        None  None  None  None  None
# profile_path          None  None  None  None  None
# adult                  NaN   NaN   NaN   NaN   NaN
# imdb_id               None  None  None  None  None
# homepage              None  None  None  None  None

# %%
df_600k.tail()
# Out:
#       birthday known_for_department deathday  id  name also_known_as  gender  \
# 99995     None                 None     None NaN  None          None     NaN
# 99996     None                 None     None NaN  None          None     NaN
# 99997     None                 None     None NaN  None          None     NaN
# 99998     None                 None     None NaN  None          None     NaN
# 99999     None                 None     None NaN  None          None     NaN
#
#       biography  popularity place_of_birth profile_path  adult imdb_id  \
# 99995      None         NaN           None         None    NaN    None
# 99996      None         NaN           None         None    NaN    None
# 99997      None         NaN           None         None    NaN    None
# 99998      None         NaN           None         None    NaN    None
# 99999      None         NaN           None         None    NaN    None
#
#       homepage
# 99995     None
# 99996     None
# 99997     None
# 99998     None
# 99999     None

# %%
df = pd.DataFrame(get_people(num=700000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              143 non-null    object
#  1   known_for_department  440 non-null    object
#  2   deathday              73 non-null     object
#  3   id                    440 non-null    float64
#  4   name                  440 non-null    object
#  5   also_known_as         440 non-null    object
#  6   gender                440 non-null    float64
#  7   biography             440 non-null    object
#  8   popularity            440 non-null    float64
#  9   place_of_birth        103 non-null    object
#  10  profile_path          104 non-null    object
#  11  adult                 440 non-null    object
#  12  imdb_id               440 non-null    object
#  13  homepage              4 non-null      object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_700k.json')

# %%
df_700k = pd.read_json('tmdb_person_700k.json')
df_700k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              143 non-null    object
#  1   known_for_department  440 non-null    object
#  2   deathday              73 non-null     object
#  3   id                    440 non-null    float64
#  4   name                  440 non-null    object
#  5   also_known_as         440 non-null    object
#  6   gender                440 non-null    float64
#  7   biography             440 non-null    object
#  8   popularity            440 non-null    float64
#  9   place_of_birth        103 non-null    object
#  10  profile_path          104 non-null    object
#  11  adult                 440 non-null    float64
#  12  imdb_id               440 non-null    object
#  13  homepage              4 non-null      object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_700k.head().transpose()
# Out:
#                          0     1     2     3     4
# birthday              None  None  None  None  None
# known_for_department  None  None  None  None  None
# deathday              None  None  None  None  None
# id                     NaN   NaN   NaN   NaN   NaN
# name                  None  None  None  None  None
# also_known_as         None  None  None  None  None
# gender                 NaN   NaN   NaN   NaN   NaN
# biography             None  None  None  None  None
# popularity             NaN   NaN   NaN   NaN   NaN
# place_of_birth        None  None  None  None  None
# profile_path          None  None  None  None  None
# adult                  NaN   NaN   NaN   NaN   NaN
# imdb_id               None  None  None  None  None
# homepage              None  None  None  None  None

# %%
df_700k.tail()
# Out:
#       birthday known_for_department deathday  id  name also_known_as  gender  \
# 99995     None                 None     None NaN  None          None     NaN
# 99996     None                 None     None NaN  None          None     NaN
# 99997     None                 None     None NaN  None          None     NaN
# 99998     None                 None     None NaN  None          None     NaN
# 99999     None                 None     None NaN  None          None     NaN
#
#       biography  popularity place_of_birth profile_path  adult imdb_id  \
# 99995      None         NaN           None         None    NaN    None
# 99996      None         NaN           None         None    NaN    None
# 99997      None         NaN           None         None    NaN    None
# 99998      None         NaN           None         None    NaN    None
# 99999      None         NaN           None         None    NaN    None
#
#       homepage
# 99995     None
# 99996     None
# 99997     None
# 99998     None
# 99999     None

# %%
df = pd.DataFrame(get_people(num=800000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              33 non-null     object
#  1   known_for_department  163 non-null    object
#  2   deathday              17 non-null     object
#  3   id                    163 non-null    float64
#  4   name                  163 non-null    object
#  5   also_known_as         163 non-null    object
#  6   gender                163 non-null    float64
#  7   biography             163 non-null    object
#  8   popularity            163 non-null    float64
#  9   place_of_birth        24 non-null     object
#  10  profile_path          26 non-null     object
#  11  adult                 163 non-null    object
#  12  imdb_id               163 non-null    object
#  13  homepage              3 non-null      object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_800k.json')

# %%
df_800k = pd.read_json('tmdb_person_800k.json')
df_800k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              33 non-null     object
#  1   known_for_department  163 non-null    object
#  2   deathday              17 non-null     object
#  3   id                    163 non-null    float64
#  4   name                  163 non-null    object
#  5   also_known_as         163 non-null    object
#  6   gender                163 non-null    float64
#  7   biography             163 non-null    object
#  8   popularity            163 non-null    float64
#  9   place_of_birth        24 non-null     object
#  10  profile_path          26 non-null     object
#  11  adult                 163 non-null    float64
#  12  imdb_id               163 non-null    object
#  13  homepage              3 non-null      object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_800k.head().transpose()
# Out:
#                          0     1     2     3     4
# birthday              None  None  None  None  None
# known_for_department  None  None  None  None  None
# deathday              None  None  None  None  None
# id                     NaN   NaN   NaN   NaN   NaN
# name                  None  None  None  None  None
# also_known_as         None  None  None  None  None
# gender                 NaN   NaN   NaN   NaN   NaN
# biography             None  None  None  None  None
# popularity             NaN   NaN   NaN   NaN   NaN
# place_of_birth        None  None  None  None  None
# profile_path          None  None  None  None  None
# adult                  NaN   NaN   NaN   NaN   NaN
# imdb_id               None  None  None  None  None
# homepage              None  None  None  None  None

# %%
df_800k.tail()
# Out:
#       birthday known_for_department deathday  id  name also_known_as  gender  \
# 99995     None                 None     None NaN  None          None     NaN
# 99996     None                 None     None NaN  None          None     NaN
# 99997     None                 None     None NaN  None          None     NaN
# 99998     None                 None     None NaN  None          None     NaN
# 99999     None                 None     None NaN  None          None     NaN
#
#       biography  popularity place_of_birth profile_path  adult imdb_id  \
# 99995      None         NaN           None         None    NaN    None
# 99996      None         NaN           None         None    NaN    None
# 99997      None         NaN           None         None    NaN    None
# 99998      None         NaN           None         None    NaN    None
# 99999      None         NaN           None         None    NaN    None
#
#       homepage
# 99995     None
# 99996     None
# 99997     None
# 99998     None
# 99999     None

# %%
df = pd.DataFrame(get_people(num=900000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              54 non-null     object
#  1   known_for_department  284 non-null    object
#  2   deathday              4 non-null      object
#  3   id                    284 non-null    float64
#  4   name                  284 non-null    object
#  5   also_known_as         284 non-null    object
#  6   gender                284 non-null    float64
#  7   biography             284 non-null    object
#  8   popularity            284 non-null    float64
#  9   place_of_birth        42 non-null     object
#  10  profile_path          47 non-null     object
#  11  adult                 284 non-null    object
#  12  imdb_id               284 non-null    object
#  13  homepage              8 non-null      object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_900k.json')

# %%
df_900k = pd.read_json('tmdb_person_900k.json')
df_900k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              54 non-null     object
#  1   known_for_department  284 non-null    object
#  2   deathday              4 non-null      object
#  3   id                    284 non-null    float64
#  4   name                  284 non-null    object
#  5   also_known_as         284 non-null    object
#  6   gender                284 non-null    float64
#  7   biography             284 non-null    object
#  8   popularity            284 non-null    float64
#  9   place_of_birth        42 non-null     object
#  10  profile_path          47 non-null     object
#  11  adult                 284 non-null    float64
#  12  imdb_id               284 non-null    object
#  13  homepage              8 non-null      object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_900k.head().transpose()
# Out:
#                          0     1     2     3     4
# birthday              None  None  None  None  None
# known_for_department  None  None  None  None  None
# deathday              None  None  None  None  None
# id                     NaN   NaN   NaN   NaN   NaN
# name                  None  None  None  None  None
# also_known_as         None  None  None  None  None
# gender                 NaN   NaN   NaN   NaN   NaN
# biography             None  None  None  None  None
# popularity             NaN   NaN   NaN   NaN   NaN
# place_of_birth        None  None  None  None  None
# profile_path          None  None  None  None  None
# adult                  NaN   NaN   NaN   NaN   NaN
# imdb_id               None  None  None  None  None
# homepage              None  None  None  None  None

# %%
df_900k.tail()
# Out:
#       birthday known_for_department deathday  id  name also_known_as  gender  \
# 99995     None                 None     None NaN  None          None     NaN
# 99996     None                 None     None NaN  None          None     NaN
# 99997     None                 None     None NaN  None          None     NaN
# 99998     None                 None     None NaN  None          None     NaN
# 99999     None                 None     None NaN  None          None     NaN
#
#       biography  popularity place_of_birth profile_path  adult imdb_id  \
# 99995      None         NaN           None         None    NaN    None
# 99996      None         NaN           None         None    NaN    None
# 99997      None         NaN           None         None    NaN    None
# 99998      None         NaN           None         None    NaN    None
# 99999      None         NaN           None         None    NaN    None
#
#       homepage
# 99995     None
# 99996     None
# 99997     None
# 99998     None
# 99999     None

# %%
df = pd.DataFrame(get_people(num=1000000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              3925 non-null   object
#  1   known_for_department  18373 non-null  object
#  2   deathday              1176 non-null   object
#  3   id                    18382 non-null  float64
#  4   name                  18382 non-null  object
#  5   also_known_as         18382 non-null  object
#  6   gender                18382 non-null  float64
#  7   biography             18382 non-null  object
#  8   popularity            18382 non-null  float64
#  9   place_of_birth        3046 non-null   object
#  10  profile_path          2845 non-null   object
#  11  adult                 18382 non-null  object
#  12  imdb_id               18382 non-null  object
#  13  homepage              413 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1000k.json')

# %%
df_1000k = pd.read_json('tmdb_person_1000k.json')
df_1000k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              3925 non-null   object
#  1   known_for_department  18373 non-null  object
#  2   deathday              1176 non-null   object
#  3   id                    18382 non-null  float64
#  4   name                  18382 non-null  object
#  5   also_known_as         18382 non-null  object
#  6   gender                18382 non-null  float64
#  7   biography             18382 non-null  object
#  8   popularity            18382 non-null  float64
#  9   place_of_birth        3046 non-null   object
#  10  profile_path          2845 non-null   object
#  11  adult                 18382 non-null  float64
#  12  imdb_id               18382 non-null  object
#  13  homepage              413 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1000k.head().transpose()
# Out:
#                          0     1     2     3     4
# birthday              None  None  None  None  None
# known_for_department  None  None  None  None  None
# deathday              None  None  None  None  None
# id                     NaN   NaN   NaN   NaN   NaN
# name                  None  None  None  None  None
# also_known_as         None  None  None  None  None
# gender                 NaN   NaN   NaN   NaN   NaN
# biography             None  None  None  None  None
# popularity             NaN   NaN   NaN   NaN   NaN
# place_of_birth        None  None  None  None  None
# profile_path          None  None  None  None  None
# adult                  NaN   NaN   NaN   NaN   NaN
# imdb_id               None  None  None  None  None
# homepage              None  None  None  None  None

# %%
df_1000k.tail()
# Out:
#          birthday known_for_department    deathday        id            name  \
# 99995  1922-06-22               Acting  1973-12-17  999996.0   María Douglas
# 99996        None               Acting        None  999997.0  Alejandro Lugo
# 99997        None                 None        None       NaN            None
# 99998        None               Acting        None  999999.0   Osvaldo Bonet
# 99999        None                 None        None       NaN            None
#
#                                         also_known_as  gender  \
# 99995  [Mary Douglas, María Duglas, Claudia Monterde]     1.0
# 99996                                              []     0.0
# 99997                                            None     NaN
# 99998                                              []     0.0
# 99999                                            None     NaN
#
#                                                biography  popularity  \
# 99995  María Douglas (June 22, 1922 – December 17, 19...         0.6
# 99996                                                            0.6
# 99997                                               None         NaN
# 99998                                                            0.6
# 99999                                               None         NaN
#
#             place_of_birth                      profile_path  adult  \
# 99995  Mexico City, Mexico  /y19u8s3ur4xDqLUPHQjb053HWqK.jpg    0.0
# 99996                 None                              None    0.0
# 99997                 None                              None    NaN
# 99998                 None                              None    0.0
# 99999                 None                              None    NaN
#
#          imdb_id homepage
# 99995  nm0235177     None
# 99996  nm0525231     None
# 99997       None     None
# 99998  nm0094329     None
# 99999       None     None

# %%
df = pd.DataFrame(get_people(num=1100000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              6914 non-null   object
#  1   known_for_department  45484 non-null  object
#  2   deathday              2351 non-null   object
#  3   id                    45496 non-null  float64
#  4   name                  45496 non-null  object
#  5   also_known_as         45496 non-null  object
#  6   gender                45496 non-null  float64
#  7   biography             45496 non-null  object
#  8   popularity            45496 non-null  float64
#  9   place_of_birth        5544 non-null   object
#  10  profile_path          5417 non-null   object
#  11  adult                 45496 non-null  object
#  12  imdb_id               45496 non-null  object
#  13  homepage              871 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1100k.json')

# %%
df_1100k = pd.read_json('tmdb_person_1100k.json')
df_1100k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              6914 non-null   object
#  1   known_for_department  45484 non-null  object
#  2   deathday              2351 non-null   object
#  3   id                    45496 non-null  float64
#  4   name                  45496 non-null  object
#  5   also_known_as         45496 non-null  object
#  6   gender                45496 non-null  float64
#  7   biography             45496 non-null  object
#  8   popularity            45496 non-null  float64
#  9   place_of_birth        5544 non-null   object
#  10  profile_path          5417 non-null   object
#  11  adult                 45496 non-null  float64
#  12  imdb_id               45496 non-null  object
#  13  homepage              871 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1100k.head().transpose()
# Out:
#                          0     1     2     3     4
# birthday              None  None  None  None  None
# known_for_department  None  None  None  None  None
# deathday              None  None  None  None  None
# id                     NaN   NaN   NaN   NaN   NaN
# name                  None  None  None  None  None
# also_known_as         None  None  None  None  None
# gender                 NaN   NaN   NaN   NaN   NaN
# biography             None  None  None  None  None
# popularity             NaN   NaN   NaN   NaN   NaN
# place_of_birth        None  None  None  None  None
# profile_path          None  None  None  None  None
# adult                  NaN   NaN   NaN   NaN   NaN
# imdb_id               None  None  None  None  None
# homepage              None  None  None  None  None

# %%
df_1100k.tail()
# Out:
#          birthday known_for_department deathday         id  \
# 99995  1986-04-16               Acting     None  1099996.0
# 99996        None               Acting     None  1099997.0
# 99997        None                 None     None        NaN
# 99998  1974-07-11              Writing     None  1099999.0
# 99999  1972-03-20              Writing     None  1100000.0
#
#                         name        also_known_as  gender biography  \
# 99995  Paul Michael McIntosh                   []     0.0
# 99996               Tom Leon                   []     0.0
# 99997                   None                 None     NaN      None
# 99998          Denis Rodimin      [Денис Родимин]     2.0
# 99999     Aleksey Kublitskiy  [Алексей Кублицкий]     2.0
#
#        popularity          place_of_birth                      profile_path  \
# 99995       0.600  Dechmont, Scotland, UK                              None
# 99996       0.600                    None                              None
# 99997         NaN                    None                              None
# 99998       1.384     Moscow, RSFSR, USSR  /gfpEtSLzBWztHiB5ULeTK95EOUQ.jpg
# 99999       0.600                    None                              None
#
#        adult    imdb_id homepage
# 99995    0.0  nm5120031     None
# 99996    0.0  nm5120799     None
# 99997    NaN       None     None
# 99998    0.0  nm0734840     None
# 99999    0.0  nm1672378     None

# %%
df = pd.DataFrame(get_people(num=1200000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              8802 non-null   object
#  1   known_for_department  67362 non-null  object
#  2   deathday              2701 non-null   object
#  3   id                    67371 non-null  float64
#  4   name                  67371 non-null  object
#  5   also_known_as         67371 non-null  object
#  6   gender                67371 non-null  float64
#  7   biography             67371 non-null  object
#  8   popularity            67371 non-null  float64
#  9   place_of_birth        7317 non-null   object
#  10  profile_path          7304 non-null   object
#  11  adult                 67371 non-null  object
#  12  imdb_id               67371 non-null  object
#  13  homepage              1241 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1200k.json')

# %%
df_1200k = pd.read_json('tmdb_person_1200k.json')
df_1200k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              8802 non-null   object
#  1   known_for_department  67362 non-null  object
#  2   deathday              2701 non-null   object
#  3   id                    67371 non-null  float64
#  4   name                  67371 non-null  object
#  5   also_known_as         67371 non-null  object
#  6   gender                67371 non-null  float64
#  7   biography             67371 non-null  object
#  8   popularity            67371 non-null  float64
#  9   place_of_birth        7317 non-null   object
#  10  profile_path          7304 non-null   object
#  11  adult                 67371 non-null  float64
#  12  imdb_id               67371 non-null  object
#  13  homepage              1241 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1200k.head().transpose()
# Out:
#                                 0           1  \
# birthday                     None        None
# known_for_department       Acting      Acting
# deathday                     None        None
# id                        1.1e+06     1.1e+06
# name                  Martin Cook  Nick Beggs
# also_known_as                  []          []
# gender                          0           0
# biography
# popularity                    0.6         0.6
# place_of_birth               None        None
# profile_path                 None        None
# adult                           0           0
# imdb_id                 nm5000109   nm1198925
# homepage                     None        None
#
#                                                      2            3  \
# birthday                                    1970-12-24         None
# known_for_department                            Acting       Acting
# deathday                                          None         None
# id                                             1.1e+06      1.1e+06
# name                                   Marco Minnemann  Theo Travis
# also_known_as                                       []           []
# gender                                               2            0
# biography
# popularity                                       0.608          0.6
# place_of_birth                        Hannover, German         None
# profile_path          /9MRjrm1nmPxHpWVjaEiG6529TGn.jpg         None
# adult                                                0            0
# imdb_id                                      nm5227293    nm5226775
# homepage                    http://marcominnemann.com/         None
#
#                                 4
# birthday                     None
# known_for_department       Acting
# deathday                     None
# id                    1.10000e+06
# name                  Niko Tsonev
# also_known_as                  []
# gender                          0
# biography
# popularity                    0.6
# place_of_birth               None
# profile_path                 None
# adult                           0
# imdb_id                 nm2057285
# homepage                     None

# %%
df_1200k.tail()
# Out:
#          birthday known_for_department deathday         id              name  \
# 99995        None               Acting     None  1199996.0      Amber Taylor
# 99996        None              Writing     None  1199997.0         Paul Daza
# 99997        None                 None     None        NaN              None
# 99998  1962-09-09               Acting     None  1199999.0        Lehua Reid
# 99999        None            Directing     None  1200000.0  Murali Nagavally
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     1.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997          None     NaN      None         NaN           None         None
# 99998            []     1.0                   0.6           None         None
# 99999            []     0.0                   0.6           None         None
#
#        adult    imdb_id homepage
# 99995    0.0  nm0851958     None
# 99996    0.0  nm2413976     None
# 99997    NaN       None     None
# 99998    0.0  nm0717332     None
# 99999    0.0  nm1199770     None

# %%
df = pd.DataFrame(get_people(num=1300000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              11475 non-null  object
#  1   known_for_department  83903 non-null  object
#  2   deathday              2377 non-null   object
#  3   id                    83969 non-null  float64
#  4   name                  83969 non-null  object
#  5   also_known_as         83969 non-null  object
#  6   gender                83969 non-null  float64
#  7   biography             83969 non-null  object
#  8   popularity            83969 non-null  float64
#  9   place_of_birth        9323 non-null   object
#  10  profile_path          9154 non-null   object
#  11  adult                 83969 non-null  object
#  12  imdb_id               83969 non-null  object
#  13  homepage              1747 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1300k.json')

# %%
df_1300k = pd.read_json('tmdb_person_1300k.json')
df_1300k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              11475 non-null  object
#  1   known_for_department  83903 non-null  object
#  2   deathday              2377 non-null   object
#  3   id                    83969 non-null  float64
#  4   name                  83969 non-null  object
#  5   also_known_as         83969 non-null  object
#  6   gender                83969 non-null  float64
#  7   biography             83969 non-null  object
#  8   popularity            83969 non-null  float64
#  9   place_of_birth        9323 non-null   object
#  10  profile_path          9154 non-null   object
#  11  adult                 83969 non-null  float64
#  12  imdb_id               83969 non-null  object
#  13  homepage              1747 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1300k.head().transpose()
# Out:
#                                     0     1               2             3  \
# birthday                         None  None            None          None
# known_for_department          Writing  None         Writing        Acting
# deathday                         None  None            None          None
# id                            1.2e+06   NaN         1.2e+06       1.2e+06
# name                  C. Balachandran  None  Martin Prakatt  Vinu Kiriath
# also_known_as                      []  None              []            []
# gender                              0   NaN               0             0
# biography                              None
# popularity                        0.6   NaN             0.6           0.6
# place_of_birth                   None  None            None          None
# profile_path                     None  None            None          None
# adult                               0   NaN               0             0
# imdb_id                                None
# homepage                         None  None            None          None
#
#                                 4
# birthday                     None
# known_for_department        Sound
# deathday                     None
# id                    1.20000e+06
# name                     Euphoria
# also_known_as                  []
# gender                          0
# biography
# popularity                    0.6
# place_of_birth               None
# profile_path                 None
# adult                           0
# imdb_id
# homepage                     None

# %%
df_1300k.tail()
# Out:
#       birthday known_for_department deathday         id              name  \
# 99995     None               Acting     None  1299996.0       Vítor Ninéu
# 99996     None               Acting     None  1299997.0      Laura Ouakil
# 99997     None            Directing     None  1299998.0   Beatriz Sanchís
# 99998     None              Writing     None  1299999.0  Youssef El Sebai
# 99999     None            Directing     None  1300000.0      Dana Ben-Ari
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6   Spain, Spain         None
# 99998            []     0.0                   0.6           None         None
# 99999            []     0.0                   0.6           None         None
#
#        adult    imdb_id homepage
# 99995    0.0  nm2629452     None
# 99996    0.0                None
# 99997    0.0  nm3808149     None
# 99998    0.0  nm0252757     None
# 99999    0.0  nm5125984     None

# %%
df = pd.DataFrame(get_people(num=1400000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              8570 non-null   object
#  1   known_for_department  91393 non-null  object
#  2   deathday              2590 non-null   object
#  3   id                    91418 non-null  float64
#  4   name                  91418 non-null  object
#  5   also_known_as         91418 non-null  object
#  6   gender                91418 non-null  float64
#  7   biography             91418 non-null  object
#  8   popularity            91418 non-null  float64
#  9   place_of_birth        6818 non-null   object
#  10  profile_path          7194 non-null   object
#  11  adult                 91418 non-null  object
#  12  imdb_id               91418 non-null  object
#  13  homepage              1326 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1400k.json')

# %%
df_1400k = pd.read_json('tmdb_person_1400k.json')
df_1400k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              8570 non-null   object
#  1   known_for_department  91393 non-null  object
#  2   deathday              2590 non-null   object
#  3   id                    91418 non-null  float64
#  4   name                  91418 non-null  object
#  5   also_known_as         91418 non-null  object
#  6   gender                91418 non-null  float64
#  7   biography             91418 non-null  object
#  8   popularity            91418 non-null  float64
#  9   place_of_birth        6818 non-null   object
#  10  profile_path          7194 non-null   object
#  11  adult                 91418 non-null  float64
#  12  imdb_id               91418 non-null  object
#  13  homepage              1326 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1400k.head().transpose()
# Out:
#                                        0                 1              2  \
# birthday                            None              None           None
# known_for_department             Editing            Acting          Sound
# deathday                            None              None           None
# id                               1.3e+06           1.3e+06        1.3e+06
# name                  João Carlos Gorjão  Manuel Marcelino  Carlos Seixas
# also_known_as                         []                []             []
# gender                                 2                 0              0
# biography
# popularity                           0.6               0.6            0.6
# place_of_birth                      None              None           None
# profile_path                        None              None           None
# adult                                  0                 0              0
# imdb_id                        nm0330990         nm2860982      nm2116943
# homepage                            None              None           None
#
#                          3               4
# birthday              None            None
# known_for_department  None         Editing
# deathday              None            None
# id                     NaN     1.30000e+06
# name                  None  Manuela Gorjão
# also_known_as         None              []
# gender                 NaN               0
# biography             None
# popularity             NaN             0.6
# place_of_birth        None            None
# profile_path          None            None
# adult                  NaN               0
# imdb_id               None       nm2120772
# homepage              None            None

# %%
df_1400k.tail()
# Out:
#          birthday known_for_department    deathday         id            name  \
# 99995        None                Sound        None  1399996.0  Robert J. Litt
# 99996        None                Sound        None  1399997.0    Elliot Tyson
# 99997        None                 Crew        None  1399998.0    Harry Madsen
# 99998        None               Camera        None  1399999.0  Michael Levine
# 99999  1939-07-20               Camera  2000-05-24  1400000.0    Mike Roberts
#
#       also_known_as  gender biography  popularity  \
# 99995            []     2.0                  1.38
# 99996            []     2.0                  0.98
# 99997            []     2.0                  0.60
# 99998            []     0.0                  0.60
# 99999            []     0.0                  0.60
#
#                        place_of_birth profile_path  adult    imdb_id homepage
# 99995                            None         None    0.0  nm0514448     None
# 99996                            None         None    0.0  nm0006525     None
# 99997                            None         None    0.0  nm0535207     None
# 99998                            None         None    0.0  nm0505898     None
# 99999  Woking - Surrey - England - UK         None    0.0                None

# %%
df = pd.DataFrame(get_people(num=1500000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              6597 non-null   object
#  1   known_for_department  93862 non-null  object
#  2   deathday              1444 non-null   object
#  3   id                    93880 non-null  float64
#  4   name                  93880 non-null  object
#  5   also_known_as         93880 non-null  object
#  6   gender                93880 non-null  float64
#  7   biography             93880 non-null  object
#  8   popularity            93880 non-null  float64
#  9   place_of_birth        5880 non-null   object
#  10  profile_path          6571 non-null   object
#  11  adult                 93880 non-null  object
#  12  imdb_id               93879 non-null  object
#  13  homepage              1351 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1500k.json')

# %%
df_1500k = pd.read_json('tmdb_person_1500k.json')
df_1500k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              6597 non-null   object
#  1   known_for_department  93862 non-null  object
#  2   deathday              1444 non-null   object
#  3   id                    93880 non-null  float64
#  4   name                  93880 non-null  object
#  5   also_known_as         93880 non-null  object
#  6   gender                93880 non-null  float64
#  7   biography             93880 non-null  object
#  8   popularity            93880 non-null  float64
#  9   place_of_birth        5880 non-null   object
#  10  profile_path          6571 non-null   object
#  11  adult                 93880 non-null  float64
#  12  imdb_id               93879 non-null  object
#  13  homepage              1351 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1500k.head().transpose()
# Out:
#                                     0                                  1  \
# birthday                         None                         1959-09-15
# known_for_department           Camera                               Crew
# deathday                         None                         1998-07-17
# id                            1.4e+06                            1.4e+06
# name                  George Kontaxis                     Alvin Milliken
# also_known_as                      []  [Alvin Milliken Jr., Al Milliken]
# gender                              0                                  2
# biography
# popularity                        0.6                                0.6
# place_of_birth                   None                 Dallas, Texas, USA
# profile_path                     None                               None
# adult                               0                                  0
# imdb_id                     nm0465404                          nm0589721
# homepage                         None                               None
#
#                                 2            3                       4
# birthday                     None         None                    None
# known_for_department         Crew   Production              Production
# deathday                     None         None                    None
# id                        1.4e+06      1.4e+06             1.40000e+06
# name                  Louis Falco  Anna Wright          Yuuri Sunohara
# also_known_as                  []           []  [Youri Sunohara, 春原悠理]
# gender                          0            0                       1
# biography
# popularity                    0.6          0.6                     0.6
# place_of_birth               None         None                    None
# profile_path                 None         None                    None
# adult                           0            0                       0
# imdb_id                 nm0265931    nm0942205               nm1785532
# homepage                     None         None                    None

# %%
df_1500k.tail()
# Out:
#       birthday known_for_department deathday         id                name  \
# 99995     None            Directing     None  1499996.0      Vahe Gabuchian
# 99996     None              Writing     None  1499997.0          Jorge Cham
# 99997     None           Production     None  1499998.0  Margaret Rosenburg
# 99998     None               Acting     None  1499999.0    William Marshall
# 99999     None                 Crew     None  1500000.0       Lucie Adalind
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     2.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     0.0                   0.6           None         None
# 99999            []     0.0                   0.6           None         None
#
#        adult    imdb_id homepage
# 99995    0.0  nm4315875     None
# 99996    0.0  nm4687472     None
# 99997    0.0  nm5889739     None
# 99998    0.0  nm6801964     None
# 99999    0.0  nm1988911     None

# %%
df = pd.DataFrame(get_people(num=1600000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              5894 non-null   object
#  1   known_for_department  93874 non-null  object
#  2   deathday              1192 non-null   object
#  3   id                    93894 non-null  float64
#  4   name                  93894 non-null  object
#  5   also_known_as         93894 non-null  object
#  6   gender                93894 non-null  float64
#  7   biography             93894 non-null  object
#  8   popularity            93894 non-null  float64
#  9   place_of_birth        5543 non-null   object
#  10  profile_path          6439 non-null   object
#  11  adult                 93894 non-null  object
#  12  imdb_id               93892 non-null  object
#  13  homepage              1310 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1600k.json')

# %%
df_1600k = pd.read_json('tmdb_person_1600k.json')
df_1600k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              5894 non-null   object
#  1   known_for_department  93874 non-null  object
#  2   deathday              1192 non-null   object
#  3   id                    93894 non-null  float64
#  4   name                  93894 non-null  object
#  5   also_known_as         93894 non-null  object
#  6   gender                93894 non-null  float64
#  7   biography             93894 non-null  object
#  8   popularity            93894 non-null  float64
#  9   place_of_birth        5543 non-null   object
#  10  profile_path          6439 non-null   object
#  11  adult                 93894 non-null  float64
#  12  imdb_id               93892 non-null  object
#  13  homepage              1310 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1600k.head().transpose()
# Out:
#                               0             1              2          3  \
# birthday                   None          None           None       None
# known_for_department     Acting        Acting         Acting     Acting
# deathday                   None          None           None       None
# id                      1.5e+06       1.5e+06        1.5e+06    1.5e+06
# name                  Raj Katti  Emily Abbott  Susanna Boney   Tony Chu
# also_known_as                []            []             []         []
# gender                        0             0              0          0
# biography
# popularity                  0.6           0.6            0.6        0.6
# place_of_birth             None          None           None       None
# profile_path               None          None           None       None
# adult                         0             0              0          0
# imdb_id               nm4687003     nm4692056      nm3797087  nm4692837
# homepage                   None          None           None       None
#
#                                         4
# birthday                             None
# known_for_department               Acting
# deathday                             None
# id                            1.50000e+06
# name                  Georgette Kala-Lobé
# also_known_as                          []
# gender                                  0
# biography
# popularity                            0.6
# place_of_birth                       None
# profile_path                         None
# adult                                   0
# imdb_id                         nm7246797
# homepage                             None

# %%
df_1600k.tail()
# Out:
#       birthday known_for_department deathday         id              name  \
# 99995     None               Acting     None  1599996.0      Kazuo Aoyagi
# 99996     None               Camera     None  1599997.0  Edib Ahmetašević
# 99997     None               Camera     None  1599998.0       Mario Delić
# 99998     None               Acting     None  1599999.0       Goro Misaki
# 99999     None                Sound     None  1600000.0    Miroslav Babić
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     0.0                   0.6           None         None
# 99999            []     0.0                   0.6           None         None
#
#        adult imdb_id homepage
# 99995    0.0             None
# 99996    0.0             None
# 99997    0.0             None
# 99998    0.0             None
# 99999    0.0             None

# %%
df = pd.DataFrame(get_people(num=1700000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              5493 non-null   object
#  1   known_for_department  93367 non-null  object
#  2   deathday              999 non-null    object
#  3   id                    93393 non-null  float64
#  4   name                  93393 non-null  object
#  5   also_known_as         93393 non-null  object
#  6   gender                93393 non-null  float64
#  7   biography             93393 non-null  object
#  8   popularity            93393 non-null  float64
#  9   place_of_birth        4863 non-null   object
#  10  profile_path          6085 non-null   object
#  11  adult                 93393 non-null  object
#  12  imdb_id               93393 non-null  object
#  13  homepage              1144 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1700k.json')

# %%
df_1700k = pd.read_json('tmdb_person_1700k.json')
df_1700k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              5493 non-null   object
#  1   known_for_department  93367 non-null  object
#  2   deathday              999 non-null    object
#  3   id                    93393 non-null  float64
#  4   name                  93393 non-null  object
#  5   also_known_as         93393 non-null  object
#  6   gender                93393 non-null  float64
#  7   biography             93393 non-null  object
#  8   popularity            93393 non-null  float64
#  9   place_of_birth        4863 non-null   object
#  10  profile_path          6085 non-null   object
#  11  adult                 93393 non-null  float64
#  12  imdb_id               93393 non-null  object
#  13  homepage              1144 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1700k.head().transpose()
# Out:
#                                  0                  1             2  \
# birthday                      None               None          None
# known_for_department        Acting  Costume & Make-Up        Acting
# deathday                      None               None          None
# id                         1.6e+06            1.6e+06       1.6e+06
# name                  Yuichi Shima       Jana Schulze  Keiko Nakano
# also_known_as                   []                 []            []
# gender                           0                  0             0
# biography
# popularity                     0.6                0.6           0.6
# place_of_birth                None               None          None
# profile_path                  None               None          None
# adult                            0                  0             0
# imdb_id
# homepage                      None               None          None
#
#                                  3              4
# birthday                      None           None
# known_for_department        Camera         Acting
# deathday                      None           None
# id                         1.6e+06    1.60000e+06
# name                  Shuji Sasano  Peter Schütze
# also_known_as               [笹野修司]             []
# gender                           0              0
# biography
# popularity                     0.6            0.6
# place_of_birth                None           None
# profile_path                  None           None
# adult                            0              0
# imdb_id
# homepage                      None           None

# %%
df_1700k.tail()
# Out:
#       birthday known_for_department deathday         id              name  \
# 99995     None               Acting     None  1699996.0      Maria Galant
# 99996     None               Acting     None  1699997.0      Maria Galant
# 99997     None              Writing     None  1699998.0  Uichiro Kitazato
# 99998     None               Acting     None  1699999.0    Fabiana Amorim
# 99999     None               Camera     None  1700000.0   Yasuhiko Mitsui
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     0.0                   0.6           None         None
# 99999            []     0.0                   0.6           None         None
#
#        adult imdb_id homepage
# 99995    0.0             None
# 99996    0.0             None
# 99997    0.0             None
# 99998    0.0             None
# 99999    0.0             None

# %%
df = pd.DataFrame(get_people(num=1800000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4341 non-null   object
#  1   known_for_department  93070 non-null  object
#  2   deathday              778 non-null    object
#  3   id                    93095 non-null  float64
#  4   name                  93095 non-null  object
#  5   also_known_as         93095 non-null  object
#  6   gender                93095 non-null  float64
#  7   biography             93095 non-null  object
#  8   popularity            93095 non-null  float64
#  9   place_of_birth        4132 non-null   object
#  10  profile_path          6543 non-null   object
#  11  adult                 93095 non-null  object
#  12  imdb_id               93095 non-null  object
#  13  homepage              964 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1800k.json')

# %%
df_1800k = pd.read_json('tmdb_person_1800k.json')
df_1800k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4341 non-null   object
#  1   known_for_department  93070 non-null  object
#  2   deathday              778 non-null    object
#  3   id                    93095 non-null  float64
#  4   name                  93095 non-null  object
#  5   also_known_as         93095 non-null  object
#  6   gender                93095 non-null  float64
#  7   biography             93095 non-null  object
#  8   popularity            93095 non-null  float64
#  9   place_of_birth        4132 non-null   object
#  10  profile_path          6543 non-null   object
#  11  adult                 93095 non-null  float64
#  12  imdb_id               93095 non-null  object
#  13  homepage              964 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1800k.head().transpose()
# Out:
#                                                      0                1  \
# birthday                                          None             None
# known_for_department                         Directing       Production
# deathday                                          None             None
# id                                             1.7e+06          1.7e+06
# name                                   Dario Albertini  Olaf B. Boorsma
# also_known_as                                       []               []
# gender                                               0                0
# biography
# popularity                                         0.6              0.6
# place_of_birth                                    None             None
# profile_path          /9JXhKgbeIPOEijFconr8O4re8Bs.jpg             None
# adult                                                0                0
# imdb_id
# homepage                                          None             None
#
#                                 2                3            4
# birthday                     None             None         None
# known_for_department   Production       Production      Editing
# deathday                     None             None         None
# id                        1.7e+06          1.7e+06  1.70000e+06
# name                  Ger Loogman  Yvonne Dahlhaus   Kees Thies
# also_known_as                  []               []           []
# gender                          0                0            0
# biography
# popularity                    0.6              0.6          0.6
# place_of_birth               None             None         None
# profile_path                 None             None         None
# adult                           0                0            0
# imdb_id
# homepage                     None             None         None

# %%
df_1800k.tail()
# Out:
#       birthday known_for_department deathday         id                  name  \
# 99995     None               Acting     None  1799996.0  Lonnie Duran Tackett
# 99996     None               Acting     None  1799997.0      Mackie Richerson
# 99997     None               Acting     None  1799998.0      Jack Christopher
# 99998     None               Acting     None  1799999.0         Sean T. James
# 99999     None               Acting     None  1800000.0         Larry Reynosa
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                  0.60           None         None
# 99996            []     0.0                  0.60           None         None
# 99997            []     0.0                  0.60           None         None
# 99998            []     0.0                  1.38           None         None
# 99999            []     0.0                  0.60           None         None
#
#        adult imdb_id homepage
# 99995    0.0             None
# 99996    0.0             None
# 99997    0.0             None
# 99998    0.0             None
# 99999    0.0             None

# %%
df = pd.DataFrame(get_people(num=1900000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4568 non-null   object
#  1   known_for_department  94358 non-null  object
#  2   deathday              743 non-null    object
#  3   id                    94381 non-null  float64
#  4   name                  94381 non-null  object
#  5   also_known_as         94381 non-null  object
#  6   gender                94381 non-null  float64
#  7   biography             94381 non-null  object
#  8   popularity            94381 non-null  float64
#  9   place_of_birth        4462 non-null   object
#  10  profile_path          9558 non-null   object
#  11  adult                 94381 non-null  object
#  12  imdb_id               94381 non-null  object
#  13  homepage              1040 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_1900k.json')

# %%
df_1900k = pd.read_json('tmdb_person_1900k.json')
df_1900k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4568 non-null   object
#  1   known_for_department  94358 non-null  object
#  2   deathday              743 non-null    object
#  3   id                    94381 non-null  float64
#  4   name                  94381 non-null  object
#  5   also_known_as         94381 non-null  object
#  6   gender                94381 non-null  float64
#  7   biography             94381 non-null  object
#  8   popularity            94381 non-null  float64
#  9   place_of_birth        4462 non-null   object
#  10  profile_path          9558 non-null   object
#  11  adult                 94381 non-null  float64
#  12  imdb_id               94381 non-null  object
#  13  homepage              1040 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_1900k.head().transpose()
# Out:
#                                                0                 1  \
# birthday                                    None              None
# known_for_department                      Acting        Production
# deathday                                    None              None
# id                                       1.8e+06           1.8e+06
# name                  Maridean Mansfield Shepard  Christine Rhodes
# also_known_as                                 []                []
# gender                                         1                 1
# biography
# popularity                                   0.6               0.6
# place_of_birth                              None              None
# profile_path                                None              None
# adult                                          0                 0
# imdb_id
# homepage                                    None              None
#
#                                             2                    3  \
# birthday                           1955-06-28                 None
# known_for_department               Production              Creator
# deathday                                 None                 None
# id                                    1.8e+06              1.8e+06
# name                              Alan Forbes  Michael von Mossner
# also_known_as                              []                   []
# gender                                      0                    0
# biography
# popularity                                0.6                  0.6
# place_of_birth        Rockford, Illinois, USA                 None
# profile_path                             None                 None
# adult                                       0                    0
# imdb_id
# homepage                                 None                 None
#
#                                 4
# birthday                     None
# known_for_department       Acting
# deathday                     None
# id                    1.80000e+06
# name                   Rita Silva
# also_known_as                  []
# gender                          0
# biography
# popularity                    0.6
# place_of_birth               None
# profile_path                 None
# adult                           0
# imdb_id
# homepage                     None

# %%
df_1900k.tail()
# Out:
#       birthday known_for_department deathday         id  \
# 99995     None               Acting     None  1899996.0
# 99996     None               Acting     None  1899997.0
# 99997     None               Acting     None  1899998.0
# 99998     None               Acting     None  1899999.0
# 99999     None               Acting     None  1900000.0
#
#                                name also_known_as  gender biography  \
# 99995       Chaiyakorn Dejkajornwut            []     0.0
# 99996  Tanachai Kungcharonetanachot            []     0.0
# 99997              Anthony Marcacci            []     0.0
# 99998                  Dep Kirkland            []     2.0
# 99999                Sawyer Shipman            []     0.0
#
#        popularity place_of_birth profile_path  adult    imdb_id homepage
# 99995         0.6           None         None    0.0                None
# 99996         0.6           None         None    0.0                None
# 99997         0.6           None         None    0.0                None
# 99998         0.6           None         None    0.0  nm1625522     None
# 99999         0.6           None         None    0.0                None

# %%
df = pd.DataFrame(get_people(num=2000000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4112 non-null   object
#  1   known_for_department  94191 non-null  object
#  2   deathday              650 non-null    object
#  3   id                    94221 non-null  float64
#  4   name                  94221 non-null  object
#  5   also_known_as         94221 non-null  object
#  6   gender                94221 non-null  float64
#  7   biography             94221 non-null  object
#  8   popularity            94221 non-null  float64
#  9   place_of_birth        3804 non-null   object
#  10  profile_path          7619 non-null   object
#  11  adult                 94221 non-null  object
#  12  imdb_id               94221 non-null  object
#  13  homepage              967 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_2000k.json')

# %%
df_2000k = pd.read_json('tmdb_person_2000k.json')
df_2000k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4112 non-null   object
#  1   known_for_department  94191 non-null  object
#  2   deathday              650 non-null    object
#  3   id                    94221 non-null  float64
#  4   name                  94221 non-null  object
#  5   also_known_as         94221 non-null  object
#  6   gender                94221 non-null  float64
#  7   biography             94221 non-null  object
#  8   popularity            94221 non-null  float64
#  9   place_of_birth        3804 non-null   object
#  10  profile_path          7619 non-null   object
#  11  adult                 94221 non-null  float64
#  12  imdb_id               94221 non-null  object
#  13  homepage              967 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_2000k.head().transpose()
# Out:
#                                 0     1               2     3            4
# birthday                     None  None            None  None         None
# known_for_department       Acting  None          Acting  None       Acting
# deathday                     None  None            None  None         None
# id                        1.9e+06   NaN         1.9e+06   NaN  1.90000e+06
# name                  Mary Stofle  None  Hunter Sanchez  None   Mary Reber
# also_known_as                  []  None              []  None           []
# gender                          1   NaN               2   NaN            1
# biography                          None                  None
# popularity                    0.6   NaN             0.6   NaN          0.6
# place_of_birth               None  None            None  None         None
# profile_path                 None  None            None  None         None
# adult                           0   NaN               0   NaN            0
# imdb_id                 nm9025987  None       nm9058941  None    nm8098443
# homepage                     None  None            None  None         None

# %%
df_2000k.tail()
# Out:
#          birthday known_for_department    deathday         id  \
# 99995  1924-02-03               Acting  2011-11-03  1999996.0
# 99996        None                Sound        None  1999997.0
# 99997        None                Sound        None  1999998.0
# 99998        None                Sound        None  1999999.0
# 99999        None                 None        None        NaN
#
#                      name also_known_as  gender biography  popularity  \
# 99995     Regina Heinonen            []     1.0                   0.6
# 99996    Ashwin Gopakumar            []     0.0                   0.6
# 99997       Niranj Suresh            []     0.0                   0.6
# 99998  Manikandan Ayyappa            []     0.0                   0.6
# 99999                None          None     NaN      None         NaN
#
#       place_of_birth                      profile_path  adult imdb_id homepage
# 99995        Finland  /or3rxhVDIUq0X73ifLF0W6CWgOS.jpg    0.0             None
# 99996           None                              None    0.0             None
# 99997           None                              None    0.0             None
# 99998           None                              None    0.0             None
# 99999           None                              None    NaN    None     None

# %%
df = pd.DataFrame(get_people(num=2100000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4100 non-null   object
#  1   known_for_department  94113 non-null  object
#  2   deathday              668 non-null    object
#  3   id                    94176 non-null  float64
#  4   name                  94176 non-null  object
#  5   also_known_as         94176 non-null  object
#  6   gender                94176 non-null  float64
#  7   biography             94176 non-null  object
#  8   popularity            94176 non-null  float64
#  9   place_of_birth        3644 non-null   object
#  10  profile_path          7369 non-null   object
#  11  adult                 94176 non-null  object
#  12  imdb_id               94176 non-null  object
#  13  homepage              749 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_2100k.json')

# %%
df_2100k = pd.read_json('tmdb_person_2100k.json')
df_2100k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4100 non-null   object
#  1   known_for_department  94113 non-null  object
#  2   deathday              668 non-null    object
#  3   id                    94176 non-null  float64
#  4   name                  94176 non-null  object
#  5   also_known_as         94176 non-null  object
#  6   gender                94176 non-null  float64
#  7   biography             94176 non-null  object
#  8   popularity            94176 non-null  float64
#  9   place_of_birth        3644 non-null   object
#  10  profile_path          7369 non-null   object
#  11  adult                 94176 non-null  float64
#  12  imdb_id               94176 non-null  object
#  13  homepage              749 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_2100k.head().transpose()
# Out:
#                                   0                1              2  \
# birthday                       None             None           None
# known_for_department          Sound           Acting         Acting
# deathday                       None             None           None
# id                            2e+06            2e+06          2e+06
# name                  Shebin Mathew  Claron McFadden  Bernarda Fink
# also_known_as                    []               []             []
# gender                            0                0              0
# biography
# popularity                      0.6              0.6            0.6
# place_of_birth                 None             None           None
# profile_path                   None             None           None
# adult                             0                0              0
# imdb_id
# homepage                       None             None           None
#
#                                    3               4
# birthday                        None            None
# known_for_department          Acting          Acting
# deathday                        None            None
# id                             2e+06     2.00000e+06
# name                  Christoph Genz  Sherilyn Baird
# also_known_as                     []              []
# gender                             0               0
# biography
# popularity                       0.6           0.828
# place_of_birth                  None            None
# profile_path                    None            None
# adult                              0               0
# imdb_id
# homepage                        None            None

# %%
df_2100k.tail()
# Out:
#       birthday known_for_department deathday         id                 name  \
# 99995     None              Editing     None  2099996.0        Laura Cardona
# 99996     None               Acting     None  2099997.0       Milana Alrayes
# 99997     None               Acting     None  2099998.0       Rylee Whiteman
# 99998     None               Acting     None  2099999.0  Aubrey Michele Katz
# 99999     None           Production     None  2100000.0       Susan Benaroya
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     0.0                   0.6           None         None
# 99999            []     0.0                   0.6           None         None
#
#        adult imdb_id homepage
# 99995    0.0             None
# 99996    0.0             None
# 99997    0.0             None
# 99998    0.0             None
# 99999    0.0             None

# %%
df = pd.DataFrame(get_people(num=2200000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              3052 non-null   object
#  1   known_for_department  94606 non-null  object
#  2   deathday              415 non-null    object
#  3   id                    94628 non-null  float64
#  4   name                  94628 non-null  object
#  5   also_known_as         94628 non-null  object
#  6   gender                94628 non-null  float64
#  7   biography             94628 non-null  object
#  8   popularity            94628 non-null  float64
#  9   place_of_birth        2879 non-null   object
#  10  profile_path          8393 non-null   object
#  11  adult                 94628 non-null  object
#  12  imdb_id               94628 non-null  object
#  13  homepage              797 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_2200k.json')

# %%
df_2200k = pd.read_json('tmdb_person_2200k.json')
df_2200k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              3052 non-null   object
#  1   known_for_department  94606 non-null  object
#  2   deathday              415 non-null    object
#  3   id                    94628 non-null  float64
#  4   name                  94628 non-null  object
#  5   also_known_as         94628 non-null  object
#  6   gender                94628 non-null  float64
#  7   biography             94628 non-null  object
#  8   popularity            94628 non-null  float64
#  9   place_of_birth        2879 non-null   object
#  10  profile_path          8393 non-null   object
#  11  adult                 94628 non-null  float64
#  12  imdb_id               94628 non-null  object
#  13  homepage              797 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_2200k.head().transpose()
# Out:
#                          0                1               2  \
# birthday              None             None            None
# known_for_department  None           Acting      Production
# deathday              None             None            None
# id                     NaN          2.1e+06         2.1e+06
# name                  None  Park Kyoung-hee  Nicki Holtzman
# also_known_as         None               []              []
# gender                 NaN                0               0
# biography             None
# popularity             NaN              1.4             0.6
# place_of_birth        None             None            None
# profile_path          None             None            None
# adult                  NaN                1               0
# imdb_id               None
# homepage              None             None            None
#
#                                         3                                 4
# birthday                             None                              None
# known_for_department           Production                            Acting
# deathday                             None                              None
# id                                2.1e+06                       2.10000e+06
# name                          Sonia Dulay                     André Ceccato
# also_known_as         [Sonia Dulay Ricci]                                []
# gender                                  0                                 0
# biography
# popularity                            0.6                               0.6
# place_of_birth                       None                              None
# profile_path                         None  /hsgLJ2cxYZOr9IYuDMQf3dmWbHR.jpg
# adult                                   0                                 0
# imdb_id
# homepage                             None                              None

# %%
df_2200k.tail()
# Out:
#          birthday known_for_department deathday         id  \
# 99995  1992-06-16               Acting     None  2199996.0
# 99996        None                 None     None        NaN
# 99997        None            Directing     None  2199998.0
# 99998        None                 None     None        NaN
# 99999        None                 None     None        NaN
#
#                           name also_known_as  gender biography  popularity  \
# 99995            Jéssica Ellen            []     1.0                   0.6
# 99996                     None          None     NaN      None         NaN
# 99997  François-Xavier Destors            []     0.0                   0.6
# 99998                     None          None     NaN      None         NaN
# 99999                     None          None     NaN      None         NaN
#
#                                place_of_birth  \
# 99995  Rio de Janeiro, Rio de Janeiro, Brazil
# 99996                                    None
# 99997                                    None
# 99998                                    None
# 99999                                    None
#
#                            profile_path  adult    imdb_id homepage
# 99995  /klLAOUgXGmNwGfrvmc5rTzxwxDi.jpg    0.0  nm5221691     None
# 99996                              None    NaN       None     None
# 99997                              None    0.0                None
# 99998                              None    NaN       None     None
# 99999                              None    NaN       None     None

# %%
df = pd.DataFrame(get_people(num=2300000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              3521 non-null   object
#  1   known_for_department  94189 non-null  object
#  2   deathday              581 non-null    object
#  3   id                    94218 non-null  float64
#  4   name                  94218 non-null  object
#  5   also_known_as         94218 non-null  object
#  6   gender                94218 non-null  float64
#  7   biography             94218 non-null  object
#  8   popularity            94218 non-null  float64
#  9   place_of_birth        3362 non-null   object
#  10  profile_path          7134 non-null   object
#  11  adult                 94218 non-null  object
#  12  imdb_id               94218 non-null  object
#  13  homepage              775 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_2300k.json')

# %%
df_2300k = pd.read_json('tmdb_person_2300k.json')
df_2300k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              3521 non-null   object
#  1   known_for_department  94189 non-null  object
#  2   deathday              581 non-null    object
#  3   id                    94218 non-null  float64
#  4   name                  94218 non-null  object
#  5   also_known_as         94218 non-null  object
#  6   gender                94218 non-null  float64
#  7   biography             94218 non-null  object
#  8   popularity            94218 non-null  float64
#  9   place_of_birth        3362 non-null   object
#  10  profile_path          7134 non-null   object
#  11  adult                 94218 non-null  float64
#  12  imdb_id               94218 non-null  object
#  13  homepage              775 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_2300k.head().transpose()
# Out:
#                          0             1               2                  3  \
# birthday              None          None            None               None
# known_for_department  None     Directing          Acting  Costume & Make-Up
# deathday              None          None            None               None
# id                     NaN       2.2e+06         2.2e+06            2.2e+06
# name                  None  Ion Indolean  Yuki Takahashi     "Scotti" Scott
# also_known_as         None            []              []                 []
# gender                 NaN             0               0                  0
# biography             None
# popularity             NaN           0.6             0.6                0.6
# place_of_birth        None          None            None               None
# profile_path          None          None            None               None
# adult                  NaN             0               0                  0
# imdb_id               None
# homepage              None          None            None               None
#
#                                 4
# birthday                     None
# known_for_department         Crew
# deathday                     None
# id                    2.20000e+06
# name                  Troy Fromin
# also_known_as                  []
# gender                          0
# biography
# popularity                    0.6
# place_of_birth               None
# profile_path                 None
# adult                           0
# imdb_id
# homepage                     None

# %%
df_2300k.tail()
# Out:
#       birthday known_for_department deathday         id              name  \
# 99995     None           Production     None  2299996.0  Witold Będkowski
# 99996     None           Production     None  2299997.0      Piotr Kielar
# 99997     None           Production     None  2299998.0   Rafał Szymański
# 99998     None                Sound     None  2299999.0     Paweł Drzyzga
# 99999     None                Sound     None  2300000.0      Jakub Wanago
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     0.0                   0.6           None         None
# 99999            []     0.0                   0.6           None         None
#
#        adult imdb_id homepage
# 99995    0.0             None
# 99996    0.0             None
# 99997    0.0             None
# 99998    0.0             None
# 99999    0.0             None

# %%
df = pd.DataFrame(get_people(num=2400000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4417 non-null   object
#  1   known_for_department  95295 non-null  object
#  2   deathday              741 non-null    object
#  3   id                    95325 non-null  float64
#  4   name                  95325 non-null  object
#  5   also_known_as         95325 non-null  object
#  6   gender                95325 non-null  float64
#  7   biography             95325 non-null  object
#  8   popularity            95325 non-null  float64
#  9   place_of_birth        4105 non-null   object
#  10  profile_path          6441 non-null   object
#  11  adult                 95325 non-null  object
#  12  imdb_id               95325 non-null  object
#  13  homepage              1068 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_2400k.json')

# %%
df_2400k = pd.read_json('tmdb_person_2400k.json')
df_2400k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              4417 non-null   object
#  1   known_for_department  95295 non-null  object
#  2   deathday              741 non-null    object
#  3   id                    95325 non-null  float64
#  4   name                  95325 non-null  object
#  5   also_known_as         95325 non-null  object
#  6   gender                95325 non-null  float64
#  7   biography             95325 non-null  object
#  8   popularity            95325 non-null  float64
#  9   place_of_birth        4105 non-null   object
#  10  profile_path          6441 non-null   object
#  11  adult                 95325 non-null  float64
#  12  imdb_id               95325 non-null  object
#  13  homepage              1068 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_2400k.head().transpose()
# Out:
#                                       0                  1          2  \
# birthday                           None               None       None
# known_for_department  Costume & Make-Up  Costume & Make-Up       Crew
# deathday                           None               None       None
# id                              2.3e+06            2.3e+06    2.3e+06
# name                     Mayela Serrano         Joy Travis  Matt Emig
# also_known_as                        []                 []         []
# gender                                0                  0          0
# biography
# popularity                          0.6                0.6        0.6
# place_of_birth                     None               None       None
# profile_path                       None               None       None
# adult                                 0                  0          0
# imdb_id
# homepage                           None               None       None
#
#                                   3     4
# birthday                       None  None
# known_for_department           Crew  None
# deathday                       None  None
# id                          2.3e+06   NaN
# name                  Edward Gabree  None
# also_known_as                    []  None
# gender                            0   NaN
# biography                            None
# popularity                      0.6   NaN
# place_of_birth                 None  None
# profile_path                   None  None
# adult                             0   NaN
# imdb_id                              None
# homepage                       None  None

# %%
df_2400k.tail()
# Out:
#       birthday known_for_department deathday         id                  name  \
# 99995     None           Production     None  2399996.0    Courtney Pritchett
# 99996     None               Acting     None  2399997.0  Ingeborg Christensen
# 99997     None               Acting     None  2399998.0              Mohanlal
# 99998     None               Acting     None  2399999.0           Mirna Menon
# 99999     None               Acting     None  2400000.0        Elijah Trichon
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     0.0                   0.6           None         None
# 99999            []     2.0                   0.6           None         None
#
#        adult    imdb_id homepage
# 99995    0.0                None
# 99996    0.0                None
# 99997    0.0                None
# 99998    0.0                None
# 99999    0.0  nm3136488     None

# %%
df = pd.DataFrame(get_people(num=2500000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              2881 non-null   object
#  1   known_for_department  95801 non-null  object
#  2   deathday              394 non-null    object
#  3   id                    95815 non-null  float64
#  4   name                  95815 non-null  object
#  5   also_known_as         95815 non-null  object
#  6   gender                95815 non-null  float64
#  7   biography             95815 non-null  object
#  8   popularity            95815 non-null  float64
#  9   place_of_birth        2888 non-null   object
#  10  profile_path          6134 non-null   object
#  11  adult                 95815 non-null  object
#  12  imdb_id               95815 non-null  object
#  13  homepage              853 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_2500k.json')

# %%
df_2500k = pd.read_json('tmdb_person_2500k.json')
df_2500k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              2881 non-null   object
#  1   known_for_department  95801 non-null  object
#  2   deathday              394 non-null    object
#  3   id                    95815 non-null  float64
#  4   name                  95815 non-null  object
#  5   also_known_as         95815 non-null  object
#  6   gender                95815 non-null  float64
#  7   biography             95815 non-null  object
#  8   popularity            95815 non-null  float64
#  9   place_of_birth        2888 non-null   object
#  10  profile_path          6134 non-null   object
#  11  adult                 95815 non-null  float64
#  12  imdb_id               95815 non-null  object
#  13  homepage              853 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_2500k.head().transpose()
# Out:
#                                           0                  1  \
# birthday                               None               None
# known_for_department                 Acting            Editing
# deathday                               None               None
# id                                  2.4e+06            2.4e+06
# name                             Dalton Day  K.R. Gaurishankar
# also_known_as                            []                 []
# gender                                    2                  0
# biography
# popularity                              0.6                0.6
# place_of_birth        Atlanta, Georgia, USA               None
# profile_path                           None               None
# adult                                     0                  0
# imdb_id                           nm2189934
# homepage                               None               None
#
#                                    2            3  \
# birthday                        None         None
# known_for_department          Acting       Acting
# deathday                        None         None
# id                           2.4e+06      2.4e+06
# name                  Brandon Hender  Carl Amster
# also_known_as                     []           []
# gender                             2            0
# biography
# popularity                       0.6          0.6
# place_of_birth                  None         None
# profile_path                    None         None
# adult                              0            0
# imdb_id                    nm4442707
# homepage                        None         None
#
#                                                                       4
# birthday                                                     2001-08-17
# known_for_department                                             Acting
# deathday                                                           None
# id                                                          2.40000e+06
# name                                                      Carsen Warner
# also_known_as                                                        []
# gender                                                                2
# biography             Carsen Warner is an actor and voice over artis...
# popularity                                                        0.703
# place_of_birth                                          California, USA
# profile_path                           /9cml0G1l7DFI8nTnhcWpIwxQNB8.jpg
# adult                                                                 0
# imdb_id                                                       nm3781780
# homepage                                                           None

# %%
df_2500k.tail()
# Out:
#       birthday known_for_department deathday         id               name  \
# 99995     None       Visual Effects     None  2499996.0       Jang Hyo-sun
# 99996     None               Acting     None  2499997.0  Masayashi Kobashi
# 99997     None       Visual Effects     None  2499998.0        Jang Mi-jin
# 99998     None               Acting     None  2499999.0    Takashi Akitane
# 99999     None       Visual Effects     None  2500000.0        Jo Eun-byul
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                   0.6           None         None
# 99996            []     2.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     2.0                   0.6           None         None
# 99999            []     0.0                   0.6           None         None
#
#        adult imdb_id homepage
# 99995    0.0             None
# 99996    0.0             None
# 99997    0.0             None
# 99998    0.0             None
# 99999    0.0             None

# %%
df = pd.DataFrame(get_people(num=2600000))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              2344 non-null   object
#  1   known_for_department  96130 non-null  object
#  2   deathday              509 non-null    object
#  3   id                    96155 non-null  float64
#  4   name                  96155 non-null  object
#  5   also_known_as         96155 non-null  object
#  6   gender                96155 non-null  float64
#  7   biography             96155 non-null  object
#  8   popularity            96155 non-null  float64
#  9   place_of_birth        2134 non-null   object
#  10  profile_path          4725 non-null   object
#  11  adult                 96155 non-null  object
#  12  imdb_id               96155 non-null  object
#  13  homepage              690 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_2600k.json')

# %%
df_2600k = pd.read_json('tmdb_person_2600k.json')
df_2600k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              2344 non-null   object
#  1   known_for_department  96130 non-null  object
#  2   deathday              509 non-null    object
#  3   id                    96155 non-null  float64
#  4   name                  96155 non-null  object
#  5   also_known_as         96155 non-null  object
#  6   gender                96155 non-null  float64
#  7   biography             96155 non-null  object
#  8   popularity            96155 non-null  float64
#  9   place_of_birth        2134 non-null   object
#  10  profile_path          4725 non-null   object
#  11  adult                 96155 non-null  float64
#  12  imdb_id               96155 non-null  object
#  13  homepage              690 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_2600k.head().transpose()
# Out:
#                                 0                                      1  \
# birthday                     None                                   None
# known_for_department       Acting                                   Crew
# deathday                     None                                   None
# id                        2.5e+06                                2.5e+06
# name                  Mone Sawada                         Jung Seock-hee
# also_known_as                  []  [정석희, Seock Hee Joung, Jung Seok-hee]
# gender                          0                                      2
# biography
# popularity                    0.6                                    0.6
# place_of_birth               None                                   None
# profile_path                 None                                   None
# adult                           0                                      0
# imdb_id
# homepage                     None                                   None
#
#                                    2           3               4
# birthday                        None  1869-10-22            None
# known_for_department  Visual Effects     Writing  Visual Effects
# deathday                        None  1943-11-26            None
# id                           2.5e+06     2.5e+06     2.50000e+06
# name                     Jung Da-som  Josef Hobl   Jung Ji-hyung
# also_known_as                     []          []              []
# gender                             0           2               0
# biography
# popularity                       0.6         0.6             0.6
# place_of_birth                  None        None            None
# profile_path                    None        None            None
# adult                              0           0               0
# imdb_id                                nm1779967
# homepage                        None        None            None

# %%
df_2600k.tail()
# Out:
#       birthday known_for_department deathday         id             name  \
# 99995     None               Acting     None  2599996.0     Heiko Röcher
# 99996     None            Directing     None  2599997.0         Mark Row
# 99997     None           Production     None  2599998.0    Tim MacDonald
# 99998     None           Production     None  2599999.0         Iain Row
# 99999     None               Acting     None  2600000.0  Miloslav Vajnar
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     0.0                   0.6           None         None
# 99999            []     2.0                   0.6           None         None
#
#        adult    imdb_id homepage
# 99995    0.0                None
# 99996    0.0                None
# 99997    0.0                None
# 99998    0.0                None
# 99999    0.0  nm7650887     None

# %%
df = pd.DataFrame(get_people(num=2618075))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              2230 non-null   object
#  1   known_for_department  96777 non-null  object
#  2   deathday              448 non-null    object
#  3   id                    96803 non-null  float64
#  4   name                  96803 non-null  object
#  5   also_known_as         96803 non-null  object
#  6   gender                96803 non-null  float64
#  7   biography             96803 non-null  object
#  8   popularity            96803 non-null  float64
#  9   place_of_birth        2060 non-null   object
#  10  profile_path          4976 non-null   object
#  11  adult                 96803 non-null  object
#  12  imdb_id               96803 non-null  object
#  13  homepage              824 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 10.7+ MB

# %%
#df.to_json('tmdb_person_2700k.json')

# %%
df_2700k = pd.read_json('tmdb_person_2700k.json')
df_2700k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   birthday              2230 non-null   object
#  1   known_for_department  96777 non-null  object
#  2   deathday              448 non-null    object
#  3   id                    96803 non-null  float64
#  4   name                  96803 non-null  object
#  5   also_known_as         96803 non-null  object
#  6   gender                96803 non-null  float64
#  7   biography             96803 non-null  object
#  8   popularity            96803 non-null  float64
#  9   place_of_birth        2060 non-null   object
#  10  profile_path          4976 non-null   object
#  11  adult                 96803 non-null  float64
#  12  imdb_id               96803 non-null  object
#  13  homepage              824 non-null    object
# dtypes: float64(4), object(10)
# memory usage: 11.4+ MB

# %%
df_2700k.head().transpose()
# Out:
#                                 0               1            2            3  \
# birthday                     None            None         None         None
# known_for_department       Acting          Acting       Acting       Acting
# deathday                     None            None         None         None
# id                    2.51808e+06     2.51808e+06  2.51808e+06  2.51808e+06
# name                    David Rau  Getenesh Berhe  Leo Kleiber     Finn Mai
# also_known_as                  []              []           []           []
# gender                          0               0            0            0
# biography
# popularity                    0.6             0.6          0.6          0.6
# place_of_birth               None            None         None         None
# profile_path                 None            None         None         None
# adult                           0               0            0            0
# imdb_id
# homepage                     None            None         None         None
#
#                                      4
# birthday                          None
# known_for_department            Acting
# deathday                          None
# id                         2.51808e+06
# name                  Andreas Heermann
# also_known_as                       []
# gender                               0
# biography
# popularity                         0.6
# place_of_birth                    None
# profile_path                      None
# adult                                0
# imdb_id
# homepage                          None

# %%
df_2700k.tail()
# Out:
#       birthday known_for_department deathday         id                name  \
# 99995     None    Costume & Make-Up     None  2618071.0   Daphne Xiaoru Jia
# 99996     None               Acting     None  2618072.0    Emmanuel Camacho
# 99997     None            Directing     None  2618073.0        Matthew Boda
# 99998     None              Writing     None  2618074.0  Alessandro Bilotta
# 99999     None            Directing     None  2618075.0       Jelena Jovčić
#
#       also_known_as  gender biography  popularity place_of_birth profile_path  \
# 99995            []     0.0                   0.6           None         None
# 99996            []     0.0                   0.6           None         None
# 99997            []     0.0                   0.6           None         None
# 99998            []     0.0                   0.6           None         None
# 99999            []     0.0                   0.6           None         None
#
#        adult imdb_id homepage
# 99995    0.0             None
# 99996    0.0             None
# 99997    0.0             None
# 99998    0.0             None
# 99999    0.0             None

# %%
df_100k
# Out:
#          birthday known_for_department    deathday        id  \
# 0      1944-05-14            Directing        None       1.0
# 1      1951-09-25               Acting        None       2.0
# 2      1942-07-13               Acting        None       3.0
# 3      1956-10-21               Acting  2016-12-27       4.0
# 4      1913-05-26               Acting  1994-08-11       5.0
# ...           ...                  ...         ...       ...
# 99995        None               Acting        None   99996.0
# 99996        None            Directing        None   99997.0
# 99997        None               Acting        None   99998.0
# 99998        None               Acting        None   99999.0
# 99999        None               Acting        None  100000.0
#
#                    name                                      also_known_as  \
# 0          George Lucas  [George Walton Lucas Jr. , 乔治·卢卡斯, Джордж Лука...
# 1           Mark Hamill  [Mark Hamil, Mark Richard Hamill, Марк Хэмилл,...
# 2         Harrison Ford  [Гаррісон Форд, Харрисон Форд, هاريسون فورد, 해...
# 3         Carrie Fisher  [Carrie Frances Fisher , Кэрри Фишер, Кэрри Фр...
# 4         Peter Cushing                             [Peter Wilton Cushing]
# ...                 ...                                                ...
# 99995    Scooter McCrae                                                 []
# 99996     Eric Thornett                                                 []
# 99997       Jason Wauer                                                 []
# 99998             Mr. ?                                                 []
# 99999  Demetrius Parker                                                 []
#
#        gender                                          biography  popularity  \
# 0         2.0  George Walton Lucas Jr. (born May 14, 1944) is...       6.761
# 1         2.0  Mark Richard Hamill (born September 25, 1951) ...      10.497
# 2         2.0  Legendary Hollywood Icon Harrison Ford was bor...      20.349
# 3         1.0  Carrie Frances Fisher (21 October 1956 - 27 De...       7.228
# 4         2.0  Peter Wilton Cushing, OBE  (26 May 1913 – 11 A...       3.902
# ...       ...                                                ...         ...
# 99995     0.0                                                          0.631
# 99996     0.0                                                          0.600
# 99997     0.0                                                          0.600
# 99998     0.0                                                          0.600
# 99999     0.0                                                          0.600
#
#                                     place_of_birth  \
# 0                         Modesto, California, USA
# 1                         Concord, California, USA
# 2                           Chicago, Illinois, USA
# 3      Beverly Hills, Los Angeles, California, USA
# 4                      Kenley, Surrey, England, UK
# ...                                            ...
# 99995                                         None
# 99996                                         None
# 99997                                         None
# 99998                                         None
# 99999                                         None
#
#                            profile_path  adult    imdb_id  \
# 0      /mDLDvsx8PaZoEThkBdyaG1JxPdf.jpg    0.0  nm0000184
# 1      /fk8OfdReNltKZqOk2TZgkofCUFq.jpg    0.0  nm0000434
# 2      /5M7oN3sznp99hWYQ9sX0xheswWX.jpg    0.0  nm0000148
# 3      /rfJtncHewKVnHjqpIZvjn24ESeC.jpg    0.0  nm0000402
# 4       /1qtKVu16REL2YLVrhayjVey4al.jpg    0.0  nm0001088
# ...                                 ...    ...        ...
# 99995                              None    0.0  nm0566885
# 99996                              None    0.0  nm1204419
# 99997                              None    0.0  nm1312267
# 99998                              None    0.0  nm2425757
# 99999                              None    0.0  nm1203784
#
#                         homepage
# 0                           None
# 1                           None
# 2                           None
# 3      https://carriefisher.com/
# 4                           None
# ...                          ...
# 99995                       None
# 99996                       None
# 99997                       None
# 99998                       None
# 99999                       None
#
# [100000 rows x 14 columns]

# %%
raise SystemExit("Stop right there!")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stop right there!
# /home/lord_black/anaconda3/envs/movieCap1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# last_person = 2618075

# %% [markdown]
# def get_people():
#     """Makes requests for all person objects in TMDb database and stores them in a list of JSON's"""
#     people_list = []
#     for val in range(11, 20):
#         print(val)
#         clear_output(wait=True)
#         url = base_url + 'person/' + str(val) + '?api_key=' + my_key
#         response = requests.get(url)
#         if response.status_code != 200:
#             continue
#         people_list.append(response.json())
#     return people_list

# %%
#pd.DataFrame(get_people()).to_json('tmdb_person_objects.json')
